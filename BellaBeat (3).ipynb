# %%
#Importing libraries for analysis and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading data into a variable and checking the datatype of each column
da = pd.read_csv('dailyActivity_merged.csv') 
da.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
#Change the ActivityDate from object to Date datatype and store in a new column
da["ActiveDate"] = pd.to_datetime(da["ActivityDate"])
da["ActiveDate"].dtype
pd.set_option('display.max_rows', 10)
da.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# min                    0.000000            0.000000                  0.000000
# 25%                    0.000000            0.000000                  0.000000
# 50%                    0.000000            0.210000                  0.240000
# 75%                    0.000000            2.052500                  0.800000
# max                    4.942142           21.920000                  6.480000
#
#        LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# count           940.000000               940.000000         940.000000
# mean              3.340819                 0.001606          21.164894
# std               2.040655                 0.007346          32.844803
# min               0.000000                 0.000000           0.000000
# 25%               1.945000                 0.000000           0.000000
# 50%               3.365000                 0.000000           4.000000
# 75%               4.782500                 0.000000          32.000000
# max              10.710000                 0.110000         210.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count           940.000000            940.000000        940.000000
# mean             13.564894            192.812766        991.210638
# std              19.987404            109.174700        301.267437
# min               0.000000              0.000000          0.000000
# 25%               0.000000            127.000000        729.750000
# 50%               6.000000            199.000000       1057.500000
# 75%              19.000000            264.000000       1229.500000
# max             143.000000            518.000000       1440.000000
#
#           Calories
# count   940.000000
# mean   2303.609574
# std     718.166862
# min       0.000000
# 25%    1828.500000
# 50%    2134.000000
# 75%    2793.250000
# max    4900.000000

# %%
da.to_csv('da.csv')

# %%
da['TotalActiveMinutes'] = da['VeryActiveMinutes']+da['FairlyActiveMinutes']+da['LightlyActiveMinutes']
da['TotalActiveMinutes']
# Out:
# 0      366
# 1      257
# 2      222
# 3      272
# 4      267
#       ...
# 935    266
# 936    309
# 937    253
# 938    313
# 939    161
# Name: TotalActiveMinutes, Length: 940, dtype: int64

# %%
da['ActivityDate'].unique()
da
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                1.88                      0.55
# 1                         0.0                1.57                      0.69
# 2                         0.0                2.44                      0.40
# 3                         0.0                2.14                      1.26
# 4                         0.0                2.71                      0.41
# ..                        ...                 ...                       ...
# 935                       0.0                1.08                      0.20
# 936                       0.0               11.10                      0.80
# 937                       0.0                1.35                      0.46
# 938                       0.0               13.22                      0.41
# 939                       0.0                1.82                      0.04
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   6.06                     0.00                 25
# 1                   4.71                     0.00                 21
# 2                   3.91                     0.00                 30
# 3                   2.83                     0.00                 29
# 4                   5.04                     0.00                 36
# ..                   ...                      ...                ...
# 935                 6.80                     0.00                 17
# 936                 6.24                     0.05                 73
# 937                 6.28                     0.00                 18
# 938                 5.89                     0.00                 88
# 939                 4.25                     0.00                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# 2                     11                   181              1218      1776
# 3                     34                   209               726      1745
# 4                     10                   221               773      1863
# ..                   ...                   ...               ...       ...
# 935                    4                   245              1174      2847
# 936                   19                   217              1131      3710
# 937                   11                   224              1187      2832
# 938                   12                   213              1127      3832
# 939                    1                   137               770      1849
#
#     ActiveDate  TotalActiveMinutes
# 0   2016-04-12                 366
# 1   2016-04-13                 257
# 2   2016-04-14                 222
# 3   2016-04-15                 272
# 4   2016-04-16                 267
# ..         ...                 ...
# 935 2016-05-08                 266
# 936 2016-05-09                 309
# 937 2016-05-10                 253
# 938 2016-05-11                 313
# 939 2016-05-12                 161
#
# [940 rows x 17 columns]

# %%
#Selecting columns I will use for analysis
da0 = da[['Id', 'TotalSteps', 'TotalDistance','Calories','ActiveDate','TotalActiveMinutes','SedentaryMinutes']]
da0.describe()
# Out:
#                  Id    TotalSteps  TotalDistance     Calories  \
# count  9.400000e+02    940.000000     940.000000   940.000000
# mean   4.855407e+09   7637.910638       5.489702  2303.609574
# std    2.424805e+09   5087.150742       3.924606   718.166862
# min    1.503960e+09      0.000000       0.000000     0.000000
# 25%    2.320127e+09   3789.750000       2.620000  1828.500000
# 50%    4.445115e+09   7405.500000       5.245000  2134.000000
# 75%    6.962181e+09  10727.000000       7.712500  2793.250000
# max    8.877689e+09  36019.000000      28.030001  4900.000000
#
#        TotalActiveMinutes  SedentaryMinutes
# count          940.000000        940.000000
# mean           227.542553        991.210638
# std            121.776307        301.267437
# min              0.000000          0.000000
# 25%            146.750000        729.750000
# 50%            247.000000       1057.500000
# 75%            317.250000       1229.500000
# max            552.000000       1440.000000

# %%
da0['ActiveDate'].dtype
# Out:
# dtype('<M8[ns]')

# %%
da0['day_of_week'] = da0['ActiveDate'].dt.day_name()
da0
# Out:
# <ipython-input-9-b9159bb08328>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da0['day_of_week'] = da0['ActiveDate'].dt.day_name()
#              Id  TotalSteps  TotalDistance  Calories ActiveDate  \
# 0    1503960366       13162       8.500000      1985 2016-04-12
# 1    1503960366       10735       6.970000      1797 2016-04-13
# 2    1503960366       10460       6.740000      1776 2016-04-14
# 3    1503960366        9762       6.280000      1745 2016-04-15
# 4    1503960366       12669       8.160000      1863 2016-04-16
# ..          ...         ...            ...       ...        ...
# 935  8877689391       10686       8.110000      2847 2016-05-08
# 936  8877689391       20226      18.250000      3710 2016-05-09
# 937  8877689391       10733       8.150000      2832 2016-05-10
# 938  8877689391       21420      19.559999      3832 2016-05-11
# 939  8877689391        8064       6.120000      1849 2016-05-12
#
#      TotalActiveMinutes  SedentaryMinutes day_of_week
# 0                   366               728     Tuesday
# 1                   257               776   Wednesday
# 2                   222              1218    Thursday
# 3                   272               726      Friday
# 4                   267               773    Saturday
# ..                  ...               ...         ...
# 935                 266              1174      Sunday
# 936                 309              1131      Monday
# 937                 253              1187     Tuesday
# 938                 313              1127   Wednesday
# 939                 161               770    Thursday
#
# [940 rows x 8 columns]

# %%
da0.groupby('day_of_week')

# %%
sns.lmplot(x="Calories", y="TotalDistance", data=da0);

# %%
# fig = plt.figure(figsize= (10,5))
# plt.bar(da0['day_of_week'],da0['Calories'])
# plt.show()

# %%
# fig = plt.figure(figsize= (10,5))
# plt.bar(da0['day_of_week'],da0['TotalSteps'])
# plt.show()

# %%
#Getting the number of participants
len(da0['Id'].unique())
# Out:
# 33

# %%
#Creating bool series True for Null values
bool_series = pd.isnull(da0['TotalActiveMinutes'])

#displaying data only with TotalActiveMinutes = Null
da0[bool_series]
# Out:
# Empty DataFrame
# Columns: [Id, TotalSteps, TotalDistance, Calories, ActiveDate, TotalActiveMinutes, SedentaryMinutes, day_of_week]
# Index: []

# %%
bo=da0['TotalActiveMinutes'] == 0
da0[bo].sort_values(by=['ActiveDate'])
# Out:
#              Id  TotalSteps  TotalDistance  Calories ActiveDate  \
# 412  4388161847       10122           7.78      2955 2016-04-12
# 654  6775888955           0           0.00      1841 2016-04-12
# 597  6117666160           0           0.00      1496 2016-04-12
# 381  4319703577        7753           5.20      2115 2016-04-12
# 598  6117666160           0           0.00      1496 2016-04-13
# ..          ...         ...            ...       ...        ...
# 121  1844505072           0           0.00      1347 2016-05-11
# 153  1927972279           0           0.00      1383 2016-05-12
# 122  1844505072           0           0.00       665 2016-05-12
# 879  8583815059           0           0.00         0 2016-05-12
# 30   1503960366           0           0.00         0 2016-05-12
#
#      TotalActiveMinutes  SedentaryMinutes day_of_week
# 412                   0              1440     Tuesday
# 654                   0              1440     Tuesday
# 597                   0              1440     Tuesday
# 381                   0              1440     Tuesday
# 598                   0              1440   Wednesday
# ..                  ...               ...         ...
# 121                   0              1440   Wednesday
# 153                   0               966    Thursday
# 122                   0               711    Thursday
# 879                   0              1440    Thursday
# 30                    0              1440    Thursday
#
# [83 rows x 8 columns]

# %%
sd =pd.read_csv("sleepDay_merged.csv")
sd.to_csv('sd.csv')

# %%
sd
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# 0               346
# 1               407
# 2               442
# 3               367
# 4               712
# ..              ...
# 408             360
# 409             527
# 410             423
# 411             545
# 412             463
#
# [413 rows x 5 columns]

# %%
sd['Time']=sd['TotalTimeInBed']-sd['TotalMinutesAsleep']
sd['Time'].mean()
# Out:
# 39.171912832929785

# %%
# fig, ax = plt.subplots() # Create the figure and axes object

# # Plot the first x and y axes:
# sd.plot(x = 'Id', y = 'TotalMinutesAsleep', ax = ax) 

# sd.plot(x = 'Id', y = 'TotalTimeInBed', ax = ax, secondary_y = True)

# %%
len(sd['Id'].unique())
# Out:
# 24

# %%
sd.plot.scatter(x='TotalMinutesAsleep', y='TotalTimeInBed')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
wl =pd.read_csv("weightLogInfo_merged.csv")
wl
# Out:
#             Id                   Date    WeightKg  WeightPounds   Fat  \
# 0   1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1   1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2   1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3   2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4   2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
# ..         ...                    ...         ...           ...   ...
# 62  8877689391    5/6/2016 6:43:35 AM   85.000000    187.392923   NaN
# 63  8877689391    5/8/2016 7:35:53 AM   85.400002    188.274775   NaN
# 64  8877689391    5/9/2016 6:39:44 AM   85.500000    188.495234   NaN
# 65  8877689391   5/11/2016 6:51:47 AM   85.400002    188.274775   NaN
# 66  8877689391   5/12/2016 6:42:53 AM   84.000000    185.188300   NaN
#
#           BMI  IsManualReport          LogId
# 0   22.650000            True  1462233599000
# 1   22.650000            True  1462319999000
# 2   47.540001           False  1460509732000
# 3   21.450001            True  1461283199000
# 4   21.690001            True  1463097599000
# ..        ...             ...            ...
# 62  25.440001           False  1462517015000
# 63  25.559999           False  1462692953000
# 64  25.610001           False  1462775984000
# 65  25.559999           False  1462949507000
# 66  25.139999           False  1463035373000
#
# [67 rows x 8 columns]

# %%
wl0=wl[['Id','Date','WeightKg','BMI']]
wl0.to_csv('wl0.csv')

# %%
# df[df['ID'].duplicated() == True]
wl0[wl0['Id'].duplicated()==True]
# Out:
#             Id                   Date   WeightKg        BMI
# 1   1503960366   5/3/2016 11:59:59 PM  52.599998  22.650000
# 4   2873212765  5/12/2016 11:59:59 PM  57.299999  21.690001
# 6   4319703577   5/4/2016 11:59:59 PM  72.300003  27.379999
# 8   4558609924  4/25/2016 11:59:59 PM  70.300003  27.459999
# 9   4558609924   5/1/2016 11:59:59 PM  69.900002  27.320000
# ..         ...                    ...        ...        ...
# 62  8877689391    5/6/2016 6:43:35 AM  85.000000  25.440001
# 63  8877689391    5/8/2016 7:35:53 AM  85.400002  25.559999
# 64  8877689391    5/9/2016 6:39:44 AM  85.500000  25.610001
# 65  8877689391   5/11/2016 6:51:47 AM  85.400002  25.559999
# 66  8877689391   5/12/2016 6:42:53 AM  84.000000  25.139999
#
# [59 rows x 4 columns]

# %%
len(wl0['Id'].unique())
# Out:
# 8

# %%
# df= pd.merge(da0,wl0,how='left',on=['Id'])

# %%
# df0=pd.merge(df,sd,how='left',on=['Id'])
# df0

# %%
id=wl0.groupby('Id')
id.mean()
# Out:
#               WeightKg        BMI
# Id
# 1503960366   52.599998  22.650000
# 1927972279  133.500000  47.540001
# 2873212765   57.000000  21.570001
# 4319703577   72.350002  27.415000
# 4558609924   69.639999  27.214000
# 5577150313   90.699997  28.000000
# 6962181067   61.553334  24.028000
# 8877689391   85.145834  25.487083

# %%
id

# %%
hs =pd.read_csv("hourlySteps_merged.csv")
hs
# Out:
#                Id           ActivityHour  StepTotal
# 0      1503960366  4/12/2016 12:00:00 AM        373
# 1      1503960366   4/12/2016 1:00:00 AM        160
# 2      1503960366   4/12/2016 2:00:00 AM        151
# 3      1503960366   4/12/2016 3:00:00 AM          0
# 4      1503960366   4/12/2016 4:00:00 AM          0
# ...           ...                    ...        ...
# 22094  8877689391  5/12/2016 10:00:00 AM        514
# 22095  8877689391  5/12/2016 11:00:00 AM       1407
# 22096  8877689391  5/12/2016 12:00:00 PM       3135
# 22097  8877689391   5/12/2016 1:00:00 PM        307
# 22098  8877689391   5/12/2016 2:00:00 PM        457
#
# [22099 rows x 3 columns]

# %%
grouped_df = hs.groupby('ActivityHour')

# for key, item in grouped_df:
#     print(grouped_df.get_group(key), "\n\n")

# %%
bo=hs['StepTotal'] == 0
hs[bo].sort_values(by=['ActivityHour'])
# Out:
#                Id           ActivityHour  StepTotal
# 15407  6775888955  4/12/2016 10:00:00 AM          0
# 9707   4388161847  4/12/2016 10:00:00 AM          0
# 14082  6117666160  4/12/2016 10:00:00 AM          0
# 19984  8583815059  4/12/2016 10:00:00 AM          0
# 8895   4057192912  4/12/2016 10:00:00 AM          0
# ...           ...                    ...        ...
# 21361  8792009665    5/9/2016 9:00:00 PM          0
# 4297   2022484408    5/9/2016 9:00:00 PM          0
# 2830   1844505072    5/9/2016 9:00:00 PM          0
# 3561   1927972279    5/9/2016 9:00:00 PM          0
# 5769   2320127002    5/9/2016 9:00:00 PM          0
#
# [9297 rows x 3 columns]

# %%
#Dropped Rows that had 0 steps
# hs.drop(hs[hs['StepTotal'] == 0].index, inplace = True)
hs
# Out:
#                Id           ActivityHour  StepTotal
# 0      1503960366  4/12/2016 12:00:00 AM        373
# 1      1503960366   4/12/2016 1:00:00 AM        160
# 2      1503960366   4/12/2016 2:00:00 AM        151
# 3      1503960366   4/12/2016 3:00:00 AM          0
# 4      1503960366   4/12/2016 4:00:00 AM          0
# ...           ...                    ...        ...
# 22094  8877689391  5/12/2016 10:00:00 AM        514
# 22095  8877689391  5/12/2016 11:00:00 AM       1407
# 22096  8877689391  5/12/2016 12:00:00 PM       3135
# 22097  8877689391   5/12/2016 1:00:00 PM        307
# 22098  8877689391   5/12/2016 2:00:00 PM        457
#
# [22099 rows x 3 columns]

# %%
#Splitted the ActivityDate into two columns for hour and date
#hs[['ActiveDate','ActiveHour']]= hs.ActivityHour.str.split(" ",1,expand=True)
# hs_new =hs[['Id','ActivityHour','StepTotal']]
# hs_new

# %%
hs[hs.duplicated()==True] #No duplicates
# Out:
# Empty DataFrame
# Columns: [Id, ActivityHour, StepTotal]
# Index: []

# %%
hc =pd.read_csv("hourlyCalories_merged.csv")
hc
# Out:
#                Id           ActivityHour  Calories
# 0      1503960366  4/12/2016 12:00:00 AM        81
# 1      1503960366   4/12/2016 1:00:00 AM        61
# 2      1503960366   4/12/2016 2:00:00 AM        59
# 3      1503960366   4/12/2016 3:00:00 AM        47
# 4      1503960366   4/12/2016 4:00:00 AM        48
# ...           ...                    ...       ...
# 22094  8877689391  5/12/2016 10:00:00 AM       126
# 22095  8877689391  5/12/2016 11:00:00 AM       192
# 22096  8877689391  5/12/2016 12:00:00 PM       321
# 22097  8877689391   5/12/2016 1:00:00 PM       101
# 22098  8877689391   5/12/2016 2:00:00 PM       113
#
# [22099 rows x 3 columns]

# %%
bo=hc['Calories'] == 0
hc[bo].sort_values(by=['ActivityHour'])
# Out:
# Empty DataFrame
# Columns: [Id, ActivityHour, Calories]
# Index: []

# %%
#Splitted the ActivityHour into a Date and an Hour column

# hc[['ActiveDate','ActiveHour']]= hc.ActivityHour.str.split(" ",1,expand=True)
# hc_new =hc[['Id','ActivityHour','Calories']]

# %%
hc[hc.duplicated()==True] #No duplicates
hc
# Out:
#                Id           ActivityHour  Calories
# 0      1503960366  4/12/2016 12:00:00 AM        81
# 1      1503960366   4/12/2016 1:00:00 AM        61
# 2      1503960366   4/12/2016 2:00:00 AM        59
# 3      1503960366   4/12/2016 3:00:00 AM        47
# 4      1503960366   4/12/2016 4:00:00 AM        48
# ...           ...                    ...       ...
# 22094  8877689391  5/12/2016 10:00:00 AM       126
# 22095  8877689391  5/12/2016 11:00:00 AM       192
# 22096  8877689391  5/12/2016 12:00:00 PM       321
# 22097  8877689391   5/12/2016 1:00:00 PM       101
# 22098  8877689391   5/12/2016 2:00:00 PM       113
#
# [22099 rows x 3 columns]

# %%
# hs_new.to_excel('hs.xlsx')
hc.to_excel('hc.xlsx')

# %%
hs
# Out:
#                Id           ActivityHour  StepTotal
# 0      1503960366  4/12/2016 12:00:00 AM        373
# 1      1503960366   4/12/2016 1:00:00 AM        160
# 2      1503960366   4/12/2016 2:00:00 AM        151
# 3      1503960366   4/12/2016 3:00:00 AM          0
# 4      1503960366   4/12/2016 4:00:00 AM          0
# ...           ...                    ...        ...
# 22094  8877689391  5/12/2016 10:00:00 AM        514
# 22095  8877689391  5/12/2016 11:00:00 AM       1407
# 22096  8877689391  5/12/2016 12:00:00 PM       3135
# 22097  8877689391   5/12/2016 1:00:00 PM        307
# 22098  8877689391   5/12/2016 2:00:00 PM        457
#
# [22099 rows x 3 columns]

# %%
new_data=pd.merge(hs,
                 hc,on='ActivityHour')

new_data
# o=new_data['Id'] == 1503960366
# new_data[o]
# Out:
#               Id_x           ActivityHour  StepTotal        Id_y  Calories
# 0       1503960366  4/12/2016 12:00:00 AM        373  1503960366        81
# 1       1503960366  4/12/2016 12:00:00 AM        373  1624580081        55
# 2       1503960366  4/12/2016 12:00:00 AM        373  1644430081        89
# 3       1503960366  4/12/2016 12:00:00 AM        373  1844505072        56
# 4       1503960366  4/12/2016 12:00:00 AM        373  1927972279        85
# ...            ...                    ...        ...         ...       ...
# 672296  4558609924   5/12/2016 3:00:00 PM        496  1927972279        86
# 672297  4558609924   5/12/2016 3:00:00 PM        496  2022484408       129
# 672298  4558609924   5/12/2016 3:00:00 PM        496  2026352035       116
# 672299  4558609924   5/12/2016 3:00:00 PM        496  2873212765       102
# 672300  4558609924   5/12/2016 3:00:00 PM        496  4558609924       111
#
# [672301 rows x 5 columns]

# %%
new_data=pd.concat([hs,hc['Calories']],axis=1)
new_data
# Out:
#                Id           ActivityHour  StepTotal  Calories
# 0      1503960366  4/12/2016 12:00:00 AM        373        81
# 1      1503960366   4/12/2016 1:00:00 AM        160        61
# 2      1503960366   4/12/2016 2:00:00 AM        151        59
# 3      1503960366   4/12/2016 3:00:00 AM          0        47
# 4      1503960366   4/12/2016 4:00:00 AM          0        48
# ...           ...                    ...        ...       ...
# 22094  8877689391  5/12/2016 10:00:00 AM        514       126
# 22095  8877689391  5/12/2016 11:00:00 AM       1407       192
# 22096  8877689391  5/12/2016 12:00:00 PM       3135       321
# 22097  8877689391   5/12/2016 1:00:00 PM        307       101
# 22098  8877689391   5/12/2016 2:00:00 PM        457       113
#
# [22099 rows x 4 columns]

# %%
new_data.to_excel('new_data.xlsx')
